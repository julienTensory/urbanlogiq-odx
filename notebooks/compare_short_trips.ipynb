# %%
from pyspark.sql import SparkSession

# Initialize a Spark session
spark = SparkSession.builder \
    .appName("CompareShortTrips") \
    .getOrCreate()
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/Users/julienrefour/Library/Caches/pypoetry/virtualenvs/odx-oGRBGo2t-py3.8/lib/python3.8/site-packages/pyspark/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/07/29 14:33:23 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
#build next stop id dataframe
from pyspark.sql import Window
from pyspark.sql import functions as F

def haversine(lat1_col, lon1_col, lat2_col, lon2_col):
    """
    Calculate the great circle distance in meters between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lat1 = F.radians(lat1_col)
    lon1 = F.radians(lon1_col)
    lat2 = F.radians(lat2_col)
    lon2 = F.radians(lon2_col)
    
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = F.sin(dlat/2)**2 + F.cos(lat1) * F.cos(lat2) * F.sin(dlon/2)**2
    c = 2 * F.asin(F.sqrt(a)) 
    r = 6371000  # Radius of earth in meters. Use 3956 for miles. Determines return value units.
    return c * r

def get_percentile_columns(column,tag,step):
    """
    This function takes a Spark DataFrame column and returns a list of columns representing
    the percentiles from 0 to 100 in 5 percent increments.
    """
    percentiles = [i for i in range(0, 100+step,step)]
    return [F.percentile_approx(column,p/100).alias(f"PERCENTILE_{p}_{tag}") for p in percentiles]

def prepare_journeys(journeys,stop_times):
    alighting_stop_window = Window.partitionBy("CARD_ID").orderBy(F.col("DATETIME").asc())
    journeys = journeys.join(stop_times.dropDuplicates(),on = ["LINE_ID","STOP_ID"],how = "left")
    journeys = journeys.dropDuplicates(["CARD_ID","JOURNEY_ID","DATETIME","EVENT"])
    journeys = journeys.withColumn(
        "EVENT_NEXT_NEXT",
        F.lead(F.col("EVENT"),2).over(alighting_stop_window)
        ).withColumn(
        "EVENT_TYPE_NEXT_NEXT",
        F.lead(F.col("EVENT_TYPE"),2).over(alighting_stop_window)
        )
    journeys = journeys.withColumn(
        "STOP_ID_NEXT",
        F.lead(F.col("STOP_ID"),1).over(alighting_stop_window)
        ).withColumn(
        "STOP_LAT_NEXT",
        F.lead(F.col("STOP_LAT"),1).over(alighting_stop_window)
        ).withColumn(
        "STOP_LON_NEXT",
        F.lead(F.col("STOP_LON"),1).over(alighting_stop_window)
        ).withColumn(
        "STOP_ID_NEXT_NEXT",
        F.lead(F.col("STOP_ID"),2).over(alighting_stop_window)
        ).withColumn(
        "STOP_LAT_NEXT_NEXT",
        F.lead(F.col("STOP_LAT"),2).over(alighting_stop_window)
        ).withColumn(
        "STOP_LON_NEXT_NEXT",
        F.lead(F.col("STOP_LON"),2).over(alighting_stop_window)
        ).withColumn(
        "DATETIME_NEXT_NEXT",
        F.lead(F.col("DATETIME"),2).over(alighting_stop_window)
        ).withColumn(
            "CONFIDENCE_NEXT",
            F.lead(F.col("CONFIDENCE"),1).over(alighting_stop_window)
        )
    journeys = journeys.withColumn("DISTANCE_TO_NEXT_STOP",haversine(
        F.col("STOP_LAT"),
        F.col("STOP_LON"),
        F.col("STOP_LAT_NEXT"),
        F.col("STOP_LON_NEXT"))
    )
    journeys = journeys.withColumn("DISTANCE_TO_NEXT_NEXT_STOP",haversine(
        F.col("STOP_LAT"),
        F.col("STOP_LON"),
        F.col("STOP_LAT_NEXT_NEXT"),
        F.col("STOP_LON_NEXT_NEXT"))
    )
    journeys = journeys.withColumn("ALIGHTING_DISTANCE_TO_NEXT_STOP",haversine(
        F.col("STOP_LAT_NEXT"),
        F.col("STOP_LON_NEXT"),
        F.col("STOP_LAT_NEXT_NEXT"),
        F.col("STOP_LON_NEXT_NEXT"))
    )
    journeys = journeys.withColumn(
        "TIME_TO_NEXT_ORIGIN",
        F.datediff(F.col("DATETIME_NEXT_NEXT"),
                F.col("DATETIME")
                ))
    return journeys

def analyze_single_leg_trips(journeys):
    single_leg_trips = journeys.filter(F.col("EVENT_TYPE") == "ORIGIN").filter(F.col("EVENT_TYPE_NEXT_NEXT") == "ORIGIN")
    single_leg_trips = single_leg_trips.withColumn(
    "IS_NULL_JOURNEY",
    F.when(
        F.col("STOP_ID")==F.col("STOP_ID_NEXT_NEXT"),
        F.lit("Y")
    ).otherwise(F.lit("N"))).withColumn(
    "IS_SINGLE_STOP_RIDE",
    F.when(
        F.col("STOP_ID_NEXT")==F.col("TRIP_STOP_ID_NEXT"),
        F.lit("Y")
    ).otherwise(F.lit("N"))
    ).withColumn("ALIGHT_AT_NEXT_START_LOCATION",
         F.when(F.col("STOP_ID_NEXT")==F.col("STOP_ID_NEXT_NEXT"),
        F.lit("Y")
    ).otherwise(F.lit("N")))
    total_count = single_leg_trips.select(F.count("*").alias("TOTAL_JOURNEYS"))
    single_leg_trips_analysis = single_leg_trips.groupBy(
        # "IS_NULL_JOURNEY",
        "IS_SINGLE_STOP_RIDE",
        "ALIGHT_AT_NEXT_START_LOCATION",
        ).agg(
    F.count("*").alias("N_JOURNEYS"),
    *[
        3.3*F.percentile_approx("ALIGHTING_DISTANCE_TO_NEXT_STOP",p/100).alias(
        f"PERCENTILE_DISTANCE_FROM_ALIGHTING_TO_NEXT_ORIGIN_{p}").cast("int")
        for p in range(0,120,20)
        ]
    )
    single_leg_trips_analysis = single_leg_trips_analysis.join(total_count)
    single_leg_trips_analysis = single_leg_trips_analysis.withColumn(
        "PERCENT_JOURNEYS",
        (100*F.col("N_JOURNEYS")/F.col("TOTAL_JOURNEYS")).cast("int")).drop("N_JOURNEYS","TOTAL_JOURNEYS")
    return single_leg_trips_analysis,single_leg_trips

# %%
stop_times = spark.read.parquet("../data/02_intermediate/stop_times_avl/stop_times")
stop_times = stop_times.dropDuplicates(["TRIP_ID","STOP_SEQUENCE"])
next_stop_window = Window.partitionBy("TRIP_ID").orderBy(F.col("STOP_SEQUENCE").asc())
stop_times = stop_times.withColumn(
    "STOP_ID_NEXT",
    F.lead(F.col("STOP_ID"),1).over(next_stop_window)
    )
stop_times = stop_times.select(
    F.col("ROUTE_ID_OLD").alias("LINE_ID"),
    F.col("STOP_ID"),
    F.col("STOP_ID_NEXT").alias("TRIP_STOP_ID_NEXT"),
    F.col("DIRECTION_ID"),
).dropDuplicates(["LINE_ID","STOP_ID","DIRECTION_ID"])
stop_times = stop_times.withColumn(
    "IS_MAX",
    F.when(F.col("LINE_ID").isin([200,190,290,90,100]),"Y").otherwise("N")
    ).cache()
n_lines_per_stop = stop_times.filter(F.col("IS_MAX") == "Y").select("STOP_ID","LINE_ID").groupBy("STOP_ID").agg(F.countDistinct(F.col("LINE_ID")).alias("N_MAX_LINES")).cache()
control_journeys = spark.read.parquet("../data/control_run_2/03_primary/rider_events_partitioned")
control_journeys = prepare_journeys(control_journeys,stop_times)
control_journeys = control_journeys.withColumn(
    "IS_MAX",
    F.when(F.col("LINE_ID").isin([200,190,290,90,100]),"Y").otherwise("N")
    ).cache()
single_leg_control_journeys_analysis,single_leg_control_journeys = analyze_single_leg_trips(control_journeys.filter(F.col("IS_MAX")=="Y"))
fixed_journeys = spark.read.parquet("../data/03_primary/rider_events_partitioned")
fixed_journeys = prepare_journeys(fixed_journeys,stop_times)
fixed_journeys = fixed_journeys.withColumn(
    "IS_MAX",
    F.when(F.col("LINE_ID").isin([200,190,290,90,100]),"Y").otherwise("N")
    ).cache()
single_leg_fixed_journeys_analysis,single_leg_fixed_journeys = analyze_single_leg_trips(fixed_journeys.filter(F.col("IS_MAX")=="Y"))
# Out:
# 24/07/29 14:37:53 WARN CacheManager: Asked to cache already cached data.
# 24/07/29 14:37:53 WARN CacheManager: Asked to cache already cached data.
# 24/07/29 14:37:54 WARN CacheManager: Asked to cache already cached data.

# %%
single_leg_control_journeys_analysis.toPandas().sort_values(
    by = ["IS_SINGLE_STOP_RIDE","ALIGHT_AT_NEXT_START_LOCATION"]
    ).T
# Out:
# 24/07/29 14:31:25 WARN MemoryStore: Not enough space to cache rdd_42_79 in memory! (computed 1572.9 KiB so far)
# 24/07/29 14:31:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_82 in memory.
# 24/07/29 14:31:25 WARN MemoryStore: Not enough space to cache rdd_42_80 in memory! (computed 1565.2 KiB so far)
# 24/07/29 14:31:25 WARN MemoryStore: Not enough space to cache rdd_42_82 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:25 WARN MemoryStore: Not enough space to cache rdd_42_81 in memory! (computed 1570.7 KiB so far)
# 24/07/29 14:31:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_85 in memory.
# 24/07/29 14:31:25 WARN MemoryStore: Not enough space to cache rdd_42_85 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_97 in memory.
# 24/07/29 14:31:25 WARN MemoryStore: Not enough space to cache rdd_42_97 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_103 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_103 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_105 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_106 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_105 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_107 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_106 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_107 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_113 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_114 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_113 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_114 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_122 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_123 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_122 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_123 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_126 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_126 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_127 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_127 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_128 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_128 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_129 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_129 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_133 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_133 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_135 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_135 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_137 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_137 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_141 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_141 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_143 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_143 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_147 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_147 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_151 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_151 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_152 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_152 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_157 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_157 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_159 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_159 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_160 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_160 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_167 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_167 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_172 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_172 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_174 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_174 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_176 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_176 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_177 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_177 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_181 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_181 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_184 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_184 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_185 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_185 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_189 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_188 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_189 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_188 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_190 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_192 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_190 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_192 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_197 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_197 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_198 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_198 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_199 in memory! (computed 3.0 MiB so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_82 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_82 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_79 in memory! (computed 1572.9 KiB so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_80 in memory! (computed 1565.2 KiB so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_81 in memory! (computed 1570.7 KiB so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_85 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_85 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_103 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_105 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_103 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_105 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_106 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_107 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_106 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_107 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_113 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_114 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_113 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_114 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_122 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_122 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_123 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_126 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_123 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_126 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_127 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_128 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_129 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_127 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_128 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_129 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_133 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_133 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_137 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_137 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_141 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_135 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_141 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_143 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_143 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_135 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_147 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_147 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_151 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_151 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_152 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_152 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_157 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_159 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_157 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_160 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_159 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_160 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_167 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_167 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_172 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_172 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_174 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_174 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_176 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_177 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_176 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_177 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_181 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_181 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_184 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_184 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_185 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_185 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_188 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_188 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_190 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_189 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_190 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_189 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_192 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_192 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_197 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_198 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_42_199 in memory.
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_197 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_198 in memory! (computed 384.0 B so far)
# 24/07/29 14:31:26 WARN MemoryStore: Not enough space to cache rdd_42_199 in memory! (computed 384.0 B so far)
#                                                            3    2         1  \
# IS_SINGLE_STOP_RIDE                                        N    N         Y
# ALIGHT_AT_NEXT_START_LOCATION                              N    Y         N
# (CAST(percentile_approx(ALIGHTING_DISTANCE_TO_N...      29.7  0.0      29.7
# (CAST(percentile_approx(ALIGHTING_DISTANCE_TO_N...     191.4  0.0    2277.0
# (CAST(percentile_approx(ALIGHTING_DISTANCE_TO_N...    1250.7  0.0    5695.8
# (CAST(percentile_approx(ALIGHTING_DISTANCE_TO_N...    6180.9  0.0   16952.1
# (CAST(percentile_approx(ALIGHTING_DISTANCE_TO_N...   23007.6  0.0   33815.1
# (CAST(percentile_approx(ALIGHTING_DISTANCE_TO_N...  179335.2  0.0  143391.6
# PERCENT_JOURNEYS                                          44   10        43
#
#                                                       0
# IS_SINGLE_STOP_RIDE                                   Y
# ALIGHT_AT_NEXT_START_LOCATION                         Y
# (CAST(percentile_approx(ALIGHTING_DISTANCE_TO_N...  0.0
# (CAST(percentile_approx(ALIGHTING_DISTANCE_TO_N...  0.0
# (CAST(percentile_approx(ALIGHTING_DISTANCE_TO_N...  0.0
# (CAST(percentile_approx(ALIGHTING_DISTANCE_TO_N...  0.0
# (CAST(percentile_approx(ALIGHTING_DISTANCE_TO_N...  0.0
# (CAST(percentile_approx(ALIGHTING_DISTANCE_TO_N...  0.0
# PERCENT_JOURNEYS                                      0

# %%
single_leg_fixed_journeys_analysis.toPandas().sort_values(
    by = ["IS_SINGLE_STOP_RIDE","ALIGHT_AT_NEXT_START_LOCATION"]
    ).T
# Out:
# 24/07/29 14:33:07 WARN MemoryStore: Not enough space to cache rdd_180_101 in memory! (computed 1506.6 KiB so far)
# 24/07/29 14:33:07 WARN BlockManager: Persisting block rdd_180_101 to disk instead.
# 24/07/29 14:33:07 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_180_106 in memory.
# 24/07/29 14:33:07 WARN MemoryStore: Not enough space to cache rdd_180_106 in memory! (computed 384.0 B so far)
# 24/07/29 14:33:07 WARN BlockManager: Persisting block rdd_180_106 to disk instead.
# 24/07/29 14:33:08 WARN MemoryStore: Not enough space to cache rdd_180_109 in memory! (computed 1499.0 KiB so far)
# 24/07/29 14:33:08 WARN BlockManager: Persisting block rdd_180_109 to disk instead.
# 24/07/29 14:33:08 WARN MemoryStore: Not enough space to cache rdd_180_110 in memory! (computed 1500.3 KiB so far)
# 24/07/29 14:33:08 WARN BlockManager: Persisting block rdd_180_110 to disk instead.
# 24/07/29 14:33:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_180_122 in memory.
# 24/07/29 14:33:10 WARN MemoryStore: Not enough space to cache rdd_180_122 in memory! (computed 384.0 B so far)
# 24/07/29 14:33:10 WARN BlockManager: Persisting block rdd_180_122 to disk instead.
# 24/07/29 14:33:10 WARN MemoryStore: Not enough space to cache rdd_180_120 in memory! (computed 1497.8 KiB so far)
# 24/07/29 14:33:10 WARN BlockManager: Persisting block rdd_180_120 to disk instead.
# 24/07/29 14:33:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_180_132 in memory.
# 24/07/29 14:33:12 WARN MemoryStore: Not enough space to cache rdd_180_132 in memory! (computed 384.0 B so far)
# 24/07/29 14:33:12 WARN BlockManager: Persisting block rdd_180_132 to disk instead.
# 24/07/29 14:33:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_180_133 in memory.
# 24/07/29 14:33:12 WARN MemoryStore: Not enough space to cache rdd_180_133 in memory! (computed 384.0 B so far)
# 24/07/29 14:33:12 WARN BlockManager: Persisting block rdd_180_133 to disk instead.
# 24/07/29 14:33:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_180_138 in memory.
# 24/07/29 14:33:12 WARN MemoryStore: Not enough space to cache rdd_180_138 in memory! (computed 384.0 B so far)
# 24/07/29 14:33:12 WARN BlockManager: Persisting block rdd_180_138 to disk instead.
# [Stage 210:========>    (136 + 8) / 200][Stage 211:>              (0 + 0) / 200]

# %%
check_fixed = single_leg_fixed_journeys.filter(
    F.col("IS_SINGLE_STOP_RIDE") == F.lit("Y")
    ).groupBy("LINE_ID").agg(F.count("*").alias("count"),F.mean(F.col("CONFIDENCE_NEXT"))).toPandas()
check_fixed["percentage"] = check_fixed["count"]/check_fixed["count"].sum()*100
view_fixed = check_fixed[check_fixed["percentage"] > 0.01].sort_values(by = ["LINE_ID"],ascending = False)

# %%
check_control = single_leg_control_journeys.filter(
    F.col("IS_SINGLE_STOP_RIDE") == F.lit("Y")
    ).groupBy("LINE_ID").agg(F.count("*").alias("count"),F.mean(F.col("CONFIDENCE_NEXT"))).toPandas()
check_control["percentage"] = check_control["count"]/check_control["count"].sum()*100
view_control = check_control[check_control["percentage"] > 0.01].sort_values(by = ["LINE_ID"],ascending = False)

# %%
compare_lines = view_control.merge(view_fixed,on = ["LINE_ID"],how = "outer",suffixes = ("_control","_fixed"))
compare_lines[sorted(compare_lines.columns)]
# Out:
#    LINE_ID  avg(CONFIDENCE_NEXT)_control  avg(CONFIDENCE_NEXT)_fixed  \
# 0      290                      0.453453                    0.451853
# 1      200                      0.437262                    0.429265
# 2      190                      0.440529                    0.423862
# 3      100                      0.467889                    0.465538
# 4       90                      0.446791                    0.446262
#
#    count_control  count_fixed  percentage_control  percentage_fixed
# 0           8554         8820           10.314723         10.493379
# 1           8107         8645            9.775714         10.285177
# 2           7761         8217            9.358495          9.775975
# 3          35178        35717           42.418908         42.493427
# 4          23330        22654           28.132160         26.952042

# %%
single_leg_control_journeys = single_leg_control_journeys.withColumn(
    "IS_MAX",
    F.when(F.col("LINE_ID").isin([200,190,290,90,100]),"Y").otherwise("N")
    )
single_leg_control_journeys.groupBy("IS_SINGLE_STOP_RIDE","IS_MAX").agg(
    F.count("*").alias("count"),
    F.mean(F.col("CONFIDENCE_NEXT")),
    F.stddev(F.col("CONFIDENCE_NEXT")),
    F.mean(F.col("ALIGHTING_DISTANCE_TO_NEXT_STOP")),
    F.stddev(F.col("ALIGHTING_DISTANCE_TO_NEXT_STOP"))).toPandas()
# Out:
#   IS_SINGLE_STOP_RIDE IS_MAX   count  avg(CONFIDENCE_NEXT)  \
# 0                   Y      Y   83042              0.455232
# 1                   N      Y  107263              0.403304
#
#    stddev_samp(CONFIDENCE_NEXT)  avg(ALIGHTING_DISTANCE_TO_NEXT_STOP)  \
# 0                      0.107998                           5426.071238
# 1                      0.185313                           2934.421983
#
#    stddev_samp(ALIGHTING_DISTANCE_TO_NEXT_STOP)
# 0                                   5973.616988
# 1                                   5146.876853

# %%
single_leg_fixed_journeys = single_leg_fixed_journeys.withColumn(
    "IS_MAX",
    F.when(F.col("LINE_ID").isin([200,190,290,90,100]),"Y").otherwise("N")
    )
single_leg_fixed_journeys.groupBy("IS_SINGLE_STOP_RIDE","IS_MAX").agg(
    F.count("*").alias("count"),
    F.mean(F.col("CONFIDENCE_NEXT")),
    F.stddev(F.col("CONFIDENCE_NEXT")),
    F.mean(F.col("ALIGHTING_DISTANCE_TO_NEXT_STOP")),
    F.stddev(F.col("ALIGHTING_DISTANCE_TO_NEXT_STOP"))).toPandas()
# Out:
#   IS_SINGLE_STOP_RIDE IS_MAX   count  avg(CONFIDENCE_NEXT)  \
# 0                   Y      Y   84166              0.451222
# 1                   N      Y  211789              0.332897
#
#    stddev_samp(CONFIDENCE_NEXT)  avg(ALIGHTING_DISTANCE_TO_NEXT_STOP)  \
# 0                      0.117370                           1162.148884
# 1                      0.229585                           3632.383292
#
#    stddev_samp(ALIGHTING_DISTANCE_TO_NEXT_STOP)
# 0                                   1601.940222
# 1                                   6207.797700

# %%
single_leg_control_journeys.filter(F.col("IS_MAX") == "Y").groupBy("IS_SINGLE_STOP_RIDE").agg(
    *[F.percentile_approx(F.col("CONFIDENCE_NEXT"),p/100) for p in range(0,120,20)]
    ).toPandas().T.sort_values(by = ["IS_SINGLE_STOP_RIDE"],axis = 1)
# Out:
#                                                        1         0
# IS_SINGLE_STOP_RIDE                                    N         Y
# percentile_approx(CONFIDENCE_NEXT, 0.0, 10000)       0.0       0.0
# percentile_approx(CONFIDENCE_NEXT, 0.2, 10000)  0.271264  0.382991
# percentile_approx(CONFIDENCE_NEXT, 0.4, 10000)  0.388828  0.426155
# percentile_approx(CONFIDENCE_NEXT, 0.6, 10000)  0.453406   0.46938
# percentile_approx(CONFIDENCE_NEXT, 0.8, 10000)  0.530042  0.524057
# percentile_approx(CONFIDENCE_NEXT, 1.0, 10000)       1.0       1.0

# %%
single_leg_fixed_journeys.filter(F.col("IS_MAX") == "Y").groupBy("IS_SINGLE_STOP_RIDE").agg(
    *[F.percentile_approx(F.col("CONFIDENCE_NEXT"),p/100) for p in range(0,120,20)]
    ).toPandas().T.sort_values(by = ["IS_SINGLE_STOP_RIDE"],axis = 1)
# Out:
#                                                        1         0
# IS_SINGLE_STOP_RIDE                                    N         Y
# percentile_approx(CONFIDENCE_NEXT, 0.0, 10000)       0.0       0.0
# percentile_approx(CONFIDENCE_NEXT, 0.2, 10000)  0.122618  0.382249
# percentile_approx(CONFIDENCE_NEXT, 0.4, 10000)  0.273273  0.427513
# percentile_approx(CONFIDENCE_NEXT, 0.6, 10000)  0.405989  0.470711
# percentile_approx(CONFIDENCE_NEXT, 0.8, 10000)  0.508939  0.524735
# percentile_approx(CONFIDENCE_NEXT, 1.0, 10000)       1.0       1.0

# %%
check_control_n_lines = single_leg_control_journeys.join(n_lines_per_stop,on = ["STOP_ID"]).groupBy("N_MAX_LINES").agg(
    F.count("*").alias("count"),
    *get_percentile_columns(F.col("CONFIDENCE_NEXT"),"CONFIDENCE",20)
    ).toPandas()
check_fixed_n_lines = single_leg_fixed_journeys.join(n_lines_per_stop,on = ["STOP_ID"]).groupBy("N_MAX_LINES").agg(
    F.count("*").alias("count"),
    *get_percentile_columns(F.col("CONFIDENCE_NEXT"),"CONFIDENCE",20)
    ).toPandas()
# Out:
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_156 in memory! (computed 1555.1 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_160 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_162 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_159 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_160 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_157 in memory! (computed 1569.3 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_163 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_162 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_159 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_163 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_161 in memory! (computed 1545.9 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_158 in memory! (computed 1557.3 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_166 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_166 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_164 in memory! (computed 1562.9 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_165 in memory! (computed 1556.1 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_167 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_167 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_170 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_168 in memory! (computed 1557.3 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_171 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_169 in memory! (computed 1567.6 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_170 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_171 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_172 in memory! (computed 1556.7 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_173 in memory! (computed 1564.7 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_174 in memory! (computed 1563.7 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_176 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_177 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_175 in memory! (computed 1564.6 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_176 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_177 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_178 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_180 in memory! (computed 1565.0 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_179 in memory! (computed 1557.7 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_178 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_181 in memory! (computed 1565.5 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_184 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_182 in memory! (computed 1559.1 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_185 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_186 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_184 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_183 in memory! (computed 1564.0 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_186 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_185 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_189 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_187 in memory! (computed 1562.9 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_190 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_188 in memory! (computed 1561.4 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_190 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_191 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_192 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_189 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_192 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_191 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_193 in memory! (computed 1563.7 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_194 in memory! (computed 1570.3 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_195 in memory! (computed 1562.0 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_197 in memory! (computed 1566.5 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_198 in memory! (computed 1567.0 KiB so far)
# 24/07/29 15:05:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_60_196 in memory.
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_196 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:05 WARN MemoryStore: Not enough space to cache rdd_60_199 in memory! (computed 1551.7 KiB so far)
# 24/07/29 15:05:09 WARN MemoryStore: Not enough space to cache rdd_134_108 in memory! (computed 3.5 MiB so far)
# 24/07/29 15:05:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_118 in memory.
# 24/07/29 15:05:09 WARN MemoryStore: Not enough space to cache rdd_134_116 in memory! (computed 3.8 MiB so far)
# 24/07/29 15:05:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_119 in memory.
# 24/07/29 15:05:09 WARN MemoryStore: Not enough space to cache rdd_134_118 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:09 WARN MemoryStore: Not enough space to cache rdd_134_119 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_122 in memory.
# 24/07/29 15:05:09 WARN MemoryStore: Not enough space to cache rdd_134_117 in memory! (computed 1500.5 KiB so far)
# 24/07/29 15:05:09 WARN MemoryStore: Not enough space to cache rdd_134_122 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:09 WARN MemoryStore: Not enough space to cache rdd_134_120 in memory! (computed 3.5 MiB so far)
# 24/07/29 15:05:09 WARN MemoryStore: Not enough space to cache rdd_134_121 in memory! (computed 3.7 MiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_123 in memory! (computed 4.2 MiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_126 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_124 in memory! (computed 3.8 MiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_127 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_125 in memory! (computed 1490.6 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_126 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_127 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_129 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_128 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_130 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_129 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_130 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_128 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_131 in memory! (computed 3.7 MiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_134 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_132 in memory! (computed 3.5 MiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_133 in memory! (computed 1494.7 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_136 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_134 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_135 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_135 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_136 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_141 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_140 in memory! (computed 1496.0 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_138 in memory! (computed 1498.7 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_141 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_139 in memory! (computed 1501.6 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_144 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_145 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_146 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_147 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_144 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_145 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_143 in memory! (computed 1502.0 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_146 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_147 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_142 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_142 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_148 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_149 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_148 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_150 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_149 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_150 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_153 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_154 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_153 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_152 in memory! (computed 1498.2 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_154 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_151 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_155 in memory! (computed 1500.2 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_151 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_156 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_156 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_158 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_157 in memory! (computed 1499.5 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_160 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_159 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_158 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_161 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_160 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_159 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_161 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_162 in memory! (computed 1494.5 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_163 in memory! (computed 1494.5 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_164 in memory! (computed 1498.1 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_165 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_167 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_165 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_167 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_166 in memory! (computed 1506.0 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_168 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_169 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_168 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_169 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_170 in memory! (computed 1502.4 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_171 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_172 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_173 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_171 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_172 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_173 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_177 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_176 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_175 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_174 in memory! (computed 1495.5 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_176 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_177 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_175 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_179 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_180 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_179 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_181 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_178 in memory! (computed 1496.8 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_180 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_181 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_183 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_182 in memory! (computed 1494.4 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_183 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_187 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_184 in memory! (computed 1504.6 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_187 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_189 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_188 in memory! (computed 1500.5 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_189 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_190 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_186 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_190 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_186 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_185 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_185 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_191 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_191 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_192 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_194 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_194 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_195 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_192 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_193 in memory! (computed 1497.6 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_195 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_197 in memory! (computed 1498.6 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_199 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_198 in memory! (computed 1496.6 KiB so far)
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_199 in memory! (computed 384.0 B so far)
# 24/07/29 15:05:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_134_196 in memory.
# 24/07/29 15:05:10 WARN MemoryStore: Not enough space to cache rdd_134_196 in memory! (computed 384.0 B so far)

# %%
check_control_n_lines.merge(check_fixed_n_lines,on = "N_MAX_LINES",suffixes=("_CONTROL","_FIXED")).sort_values(by = ["N_MAX_LINES"]).T
# Out:
#                                                0              2             1
# N_MAX_LINES                             1.000000       2.000000      3.000000
# count_CONTROL                       82556.000000   65393.000000  42339.000000
# PERCENTILE_0_CONFIDENCE_CONTROL         0.000000       0.000000      0.000000
# PERCENTILE_20_CONFIDENCE_CONTROL        0.380043       0.319018      0.342223
# PERCENTILE_40_CONFIDENCE_CONTROL        0.443069       0.386165      0.397731
# PERCENTILE_60_CONFIDENCE_CONTROL        0.489913       0.431891      0.443948
# PERCENTILE_80_CONFIDENCE_CONTROL        0.550403       0.496866      0.513840
# PERCENTILE_100_CONFIDENCE_CONTROL       1.000000       1.000000      1.000000
# count_FIXED                        119664.000000  106159.000000  70095.000000
# PERCENTILE_0_CONFIDENCE_FIXED           0.000000       0.000000      0.000000
# PERCENTILE_20_CONFIDENCE_FIXED          0.299913       0.178154      0.151348
# PERCENTILE_40_CONFIDENCE_FIXED          0.422531       0.298611      0.273401
# PERCENTILE_60_CONFIDENCE_FIXED          0.478610       0.392806      0.405715
# PERCENTILE_80_CONFIDENCE_FIXED          0.540297       0.475338      0.495155
# PERCENTILE_100_CONFIDENCE_FIXED         1.000000       1.000000      1.000000
# 24/07/29 17:04:20 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 1575863 ms exceeds timeout 120000 ms
# 24/07/29 17:04:20 WARN SparkContext: Killing executors is not supported by current scheduler.
